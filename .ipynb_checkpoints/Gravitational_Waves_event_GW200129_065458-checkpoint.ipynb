# %%
# !python -m pip install --upgrade pip
# !pip install gwpy
# !pip install matplotlib
# !pip install numpy==1.23.5 --no-cache-dir
# !pip install h5py
# !pip install pycbc
# Out:
# Requirement already satisfied: pip in c:\users\yuvra\anaconda3\lib\site-packages (25.0.1)
# Requirement already satisfied: gwpy in c:\users\yuvra\anaconda3\lib\site-packages (3.0.12)
# Requirement already satisfied: astropy>=4.3.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (6.1.0)
# Requirement already satisfied: dateparser>=1.1.4 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (1.2.1)
# Requirement already satisfied: dqsegdb2 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (1.3.0)
# Requirement already satisfied: gwdatafind>=1.1.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (1.2.0)
# Requirement already satisfied: gwosc>=0.5.3 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (0.7.2)
# Requirement already satisfied: h5py>=3.0.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (3.11.0)
# Requirement already satisfied: igwn-segments>=2.0.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (2.0.0)
# Requirement already satisfied: ligotimegps>=1.2.1 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (2.0.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (3.8.4)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (1.26.4)
# Requirement already satisfied: packaging>=24.1 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (24.2)
# Requirement already satisfied: python-dateutil in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (2.9.0.post0)
# Requirement already satisfied: requests>=2.20.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (2.32.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (1.13.1)
# Requirement already satisfied: tqdm>=4.52.0 in c:\users\yuvra\anaconda3\lib\site-packages (from gwpy) (4.66.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\yuvra\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\yuvra\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (0.2024.6.3.0.31.14)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\yuvra\anaconda3\lib\site-packages (from astropy>=4.3.0->gwpy) (6.0.1)
# Requirement already satisfied: pytz>=2024.2 in c:\users\yuvra\anaconda3\lib\site-packages (from dateparser>=1.1.4->gwpy) (2025.1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in c:\users\yuvra\anaconda3\lib\site-packages (from dateparser>=1.1.4->gwpy) (2023.10.3)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\yuvra\anaconda3\lib\site-packages (from dateparser>=1.1.4->gwpy) (5.3)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in c:\users\yuvra\anaconda3\lib\site-packages (from gwdatafind>=1.1.0->gwpy) (1.2.0)
# Requirement already satisfied: ligo-segments in c:\users\yuvra\anaconda3\lib\site-packages (from gwdatafind>=1.1.0->gwpy) (1.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib>=3.3.0->gwpy) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\yuvra\anaconda3\lib\site-packages (from python-dateutil->gwpy) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yuvra\anaconda3\lib\site-packages (from requests>=2.20.0->gwpy) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\yuvra\anaconda3\lib\site-packages (from tqdm>=4.52.0->gwpy) (0.4.6)
# Requirement already satisfied: click>=6.7 in c:\users\yuvra\anaconda3\lib\site-packages (from dqsegdb2->gwpy) (8.1.7)
# Requirement already satisfied: cryptography>=3.2 in c:\users\yuvra\anaconda3\lib\site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (42.0.5)
# Requirement already satisfied: safe-netrc>=1.0 in c:\users\yuvra\anaconda3\lib\site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.0.1)
# Requirement already satisfied: scitokens>=1.8 in c:\users\yuvra\anaconda3\lib\site-packages (from igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.8.1)
# Requirement already satisfied: tzdata in c:\users\yuvra\anaconda3\lib\site-packages (from tzlocal>=0.2->dateparser>=1.1.4->gwpy) (2023.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\yuvra\anaconda3\lib\site-packages (from cryptography>=3.2->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (1.16.0)
# Requirement already satisfied: PyJWT>=1.6.1 in c:\users\yuvra\anaconda3\lib\site-packages (from scitokens>=1.8->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (2.8.0)
# Requirement already satisfied: pycparser in c:\users\yuvra\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.2->igwn-auth-utils>=0.3.1->gwdatafind>=1.1.0->gwpy) (2.21)
# Requirement already satisfied: matplotlib in c:\users\yuvra\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yuvra\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\yuvra\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5.tar.gz (10.7 MB)
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#       --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#      - ------------------------------------- 0.5/10.7 MB 479.2 kB/s eta 0:00:22
#      -- ------------------------------------ 0.8/10.7 MB 633.2 kB/s eta 0:00:16
#      -- ------------------------------------ 0.8/10.7 MB 633.2 kB/s eta 0:00:16
#      -- ------------------------------------ 0.8/10.7 MB 633.2 kB/s eta 0:00:16
#      -- ------------------------------------ 0.8/10.7 MB 633.2 kB/s eta 0:00:16
#      --- ----------------------------------- 1.0/10.7 MB 470.4 kB/s eta 0:00:21
#      --- ----------------------------------- 1.0/10.7 MB 470.4 kB/s eta 0:00:21
#      --- ----------------------------------- 1.0/10.7 MB 470.4 kB/s eta 0:00:21
#      --- ----------------------------------- 1.0/10.7 MB 470.4 kB/s eta 0:00:21
#      ---- ---------------------------------- 1.3/10.7 MB 430.1 kB/s eta 0:00:22
#      ---- ---------------------------------- 1.3/10.7 MB 430.1 kB/s eta 0:00:22
#      ---- ---------------------------------- 1.3/10.7 MB 430.1 kB/s eta 0:00:22
#      ---- ---------------------------------- 1.3/10.7 MB 430.1 kB/s eta 0:00:22
#      ---- ---------------------------------- 1.3/10.7 MB 430.1 kB/s eta 0:00:22
#      ----- --------------------------------- 1.6/10.7 MB 369.5 kB/s eta 0:00:25
#      ----- --------------------------------- 1.6/10.7 MB 369.5 kB/s eta 0:00:25
#      ----- --------------------------------- 1.6/10.7 MB 369.5 kB/s eta 0:00:25
#      ----- --------------------------------- 1.6/10.7 MB 369.5 kB/s eta 0:00:25
#      ------ -------------------------------- 1.8/10.7 MB 358.2 kB/s eta 0:00:25
#      ------ -------------------------------- 1.8/10.7 MB 358.2 kB/s eta 0:00:25
#      ------ -------------------------------- 1.8/10.7 MB 358.2 kB/s eta 0:00:25
#      ------ -------------------------------- 1.8/10.7 MB 358.2 kB/s eta 0:00:25
#      ------ -------------------------------- 1.8/10.7 MB 358.2 kB/s eta 0:00:25
#      ------ -------------------------------- 1.8/10.7 MB 358.2 kB/s eta 0:00:25
#      ------- ------------------------------- 2.1/10.7 MB 332.7 kB/s eta 0:00:26
#      ------- ------------------------------- 2.1/10.7 MB 332.7 kB/s eta 0:00:26
#      ------------------------ -------------- 6.8/10.7 MB 291.3 kB/s eta 0:00:14
#      ------------------------ -------------- 6.8/10.7 MB 291.3 kB/s eta 0:00:14
#      ------------------------- ------------- 7.1/10.7 MB 292.8 kB/s eta 0:00:13
#      ------------------------- ------------- 7.1/10.7 MB 292.8 kB/s eta 0:00:13
#      ------------------------- ------------- 7.1/10.7 MB 292.8 kB/s eta 0:00:13
#      -------------------------- ------------ 7.3/10.7 MB 297.2 kB/s eta 0:00:12
#      --------------------------- ----------- 7.6/10.7 MB 303.5 kB/s eta 0:00:11
#      --------------------------- ----------- 7.6/10.7 MB 303.5 kB/s eta 0:00:11
#      --------------------------- ----------- 7.6/10.7 MB 303.5 kB/s eta 0:00:11
#      ---------------------------- ---------- 7.9/10.7 MB 307.0 kB/s eta 0:00:10
#      ---------------------------- ---------- 7.9/10.7 MB 307.0 kB/s eta 0:00:10
#      ----------------------------- --------- 8.1/10.7 MB 312.8 kB/s eta 0:00:09
#      ----------------------------- --------- 8.1/10.7 MB 312.8 kB/s eta 0:00:09
#      ------------------------------ -------- 8.4/10.7 MB 319.1 kB/s eta 0:00:08
#      ------------------------------- ------- 8.7/10.7 MB 325.2 kB/s eta 0:00:07
#      ------------------------------- ------- 8.7/10.7 MB 325.2 kB/s eta 0:00:07
#      -------------------------------- ------ 8.9/10.7 MB 330.9 kB/s eta 0:00:06
#      -------------------------------- ------ 8.9/10.7 MB 330.9 kB/s eta 0:00:06
#      --------------------------------- ----- 9.2/10.7 MB 334.8 kB/s eta 0:00:05
#      --------------------------------- ----- 9.2/10.7 MB 334.8 kB/s eta 0:00:05
#      ---------------------------------- ---- 9.4/10.7 MB 339.8 kB/s eta 0:00:04
#      ---------------------------------- ---- 9.4/10.7 MB 339.8 kB/s eta 0:00:04
#      ---------------------------------- ---- 9.4/10.7 MB 339.8 kB/s eta 0:00:04
#      ----------------------------------- --- 9.7/10.7 MB 341.0 kB/s eta 0:00:04
#      ----------------------------------- --- 9.7/10.7 MB 341.0 kB/s eta 0:00:04
#      ----------------------------------- --- 9.7/10.7 MB 341.0 kB/s eta 0:00:04
#      ----------------------------------- --- 9.7/10.7 MB 341.0 kB/s eta 0:00:04
#      ----------------------------------- -- 10.0/10.7 MB 339.4 kB/s eta 0:00:03
#      ----------------------------------- -- 10.0/10.7 MB 339.4 kB/s eta 0:00:03
#      ----------------------------------- -- 10.0/10.7 MB 339.4 kB/s eta 0:00:03
#      ------------------------------------ - 10.2/10.7 MB 340.7 kB/s eta 0:00:02
#      ------------------------------------ - 10.2/10.7 MB 340.7 kB/s eta 0:00:02
#      ------------------------------------ - 10.2/10.7 MB 340.7 kB/s eta 0:00:02
#      -------------------------------------  10.5/10.7 MB 342.6 kB/s eta 0:00:01
#      -------------------------------------  10.5/10.7 MB 342.6 kB/s eta 0:00:01
#      -------------------------------------  10.5/10.7 MB 342.6 kB/s eta 0:00:01
#      -------------------------------------- 10.7/10.7 MB 342.6 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [33 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\yuvra\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#     File "C:\Users\yuvra\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\yuvra\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 137, in get_requires_for_build_wheel
#       backend = _build_backend()
#                 ^^^^^^^^^^^^^^^^
#     File "C:\Users\yuvra\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 70, in _build_backend
#       obj = import_module(mod_path)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\yuvra\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#       return _bootstrap._gcd_import(name[level:], package, level)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#     File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#     File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#     File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#     File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#     File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#     File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#     File "C:\Users\yuvra\AppData\Local\Temp\pip-build-env-qn141uh6\overlay\Lib\site-packages\setuptools\__init__.py", line 16, in <module>
#       import setuptools.version
#     File "C:\Users\yuvra\AppData\Local\Temp\pip-build-env-qn141uh6\overlay\Lib\site-packages\setuptools\version.py", line 1, in <module>
#       import pkg_resources
#     File "C:\Users\yuvra\AppData\Local\Temp\pip-build-env-qn141uh6\overlay\Lib\site-packages\pkg_resources\__init__.py", line 2172, in <module>
#       register_finder(pkgutil.ImpImporter, find_on_path)
#                       ^^^^^^^^^^^^^^^^^^^
#   AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Requirement already satisfied: h5py in c:\users\yuvra\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\yuvra\anaconda3\lib\site-packages (from h5py) (1.26.4)
# ^C

# %% [markdown]
# Importing libraries

# %%
import matplotlib.pyplot as plt
from gwpy.timeseries import TimeSeries
import numpy as np
import h5py

# %% [markdown]
# Loading the data

# %%
import h5py

# Open the HDF5 file
file_path = "H-H1_GWOSC_16KHZ_R1-1264316101-32.hdf5"
with h5py.File(file_path, "r") as hdf:
    # List all groups (datasets and sub-groups)
    print("Keys:", list(hdf.keys()))

   #  # Access a specific dataset
   #  dataset_name = list(hdf.keys())[0]  # Get the first dataset name
   #  data = hdf[dataset_name][:]
    
   # print(f"Dataset: {dataset_name}")
   # print("Data:", data)
# Out:
# Keys: ['meta', 'quality', 'strain']

# %%
# File paths for H1 and L1 arms
file_H1 = "H-H1_GWOSC_16KHZ_R1-1264316101-32.hdf5"
file_L1 = "L-L1_GWOSC_16KHZ_R1-1264316101-32.hdf5"

def load_strain(file_path):
    """Loads strain data and time array from a LIGO GWOSC HDF5 file."""
    with h5py.File(file_path, "r") as hdf:
        strain = hdf["strain"]["Strain"][:]  # Extract strain data
        ts = hdf["strain"]["Strain"].attrs["Xspacing"]  # Time step size
        time = np.arange(0, len(strain) * ts, ts)  # Create time array
    return time, strain

# Load strain and time for both detectors
time_H1, strain_H1 = load_strain(file_H1)
time_L1, strain_L1 = load_strain(file_L1)

# Plot strain data for both arms
plt.figure(figsize=(10, 5), facecolor=green)
plt.plot(time_H1, strain_H1, label="H1 Strain (Hanford)", color="blue", linewidth=0.5)
plt.plot(time_L1, strain_L1, label="L1 Strain (Livingston)", color="red", linewidth=0.5, alpha=0.7)

# Formatting the plot
plt.xlabel("Time (seconds)", fontsize=12)
plt.ylabel("Strain", fontsize=12)
plt.title("LIGO Strain Data: H1 vs L1", fontsize=14)
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11     return time, strain
#      13 # Load strain and time for both detectors
# ---> 14 time_H1, strain_H1 = load_strain(file_H1)
#      15 time_L1, strain_L1 = load_strain(file_L1)
#      17 # Plot strain data for both arms
#
# Cell In[1], line 7, in load_strain(file_path)
#       5 def load_strain(file_path):
#       6     """Loads strain data and time array from a LIGO GWOSC HDF5 file."""
# ----> 7     with h5py.File(file_path, "r") as hdf:
#       8         strain = hdf["strain"]["Strain"][:]  # Extract strain data
#       9         ts = hdf["strain"]["Strain"].attrs["Xspacing"]  # Time step size
#
# NameError: name 'h5py' is not defined
